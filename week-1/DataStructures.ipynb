# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedmoinuddin98/2025-26_DS_CSA-B_MOINUDDIN_160724754098/blob/main/week-1/DataStructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2.Write a code to implement the following data structures
#a) List
#a) Tuples
#a) Dictionaries
#a) Set
ls = [10,20,30,40,50]
tu = (2,4,6,8,10,12,14)
dic = {
    "Name":"Asim",
    "Age" : 20,
    "Gender" : "Male",
}
st = {101,202,303,404,505}
print("List:- ",ls)
print("Tuples:- ",tu)
print("Dictionary:- ",dic)
print("Set:- ",st)
# Out:
# List:-  [10, 20, 30, 40, 50]
# Tuples:-  (2, 4, 6, 8, 10, 12, 14)
# Dictionary:-  {'Name': 'Asim', 'Age': 20, 'Gender': 'Male'}
# Set:-  {404, 101, 505, 202, 303}
